# %%
# please install complextensor before proceeding with the other code blocks 🫡
# !pip install complextensor
# Out:
# Requirement already satisfied: complextensor in /usr/local/lib/python3.10/dist-packages (0.1.0)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from complextensor) (2.5.0+cu121)
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.10/dist-packages (from complextensor) (1.26.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->complextensor) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->complextensor) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->complextensor) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->complextensor) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->complextensor) (2024.6.1)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->complextensor) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.8.0->complextensor) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.8.0->complextensor) (3.0.2)

# %% [markdown]
# # ComplexTensor
#
# > [ComplexTensor Github](https://github.com/NeoVertex1/ComplexTensor)
#
# Architecture Analysis
#
# * Main ComplexTensor class with real and imaginary components
# * Custom autograd Function for gradient computation
# * Comprehensive mathematical operations suite
#
# #### Core Features Examination
#
# * Basic arithmetic operations (+,-,*,/)
# * Complex functions (exp, log, sin, cos, tan)
# * FFT operations
# * Gradient manipulation capabilities
#
# #### Advanced Mathematical Operations
#
# * Polar form conversions
# * Complex activation functions
# * Quantum-inspired operations
# * Tensor manipulations
#
# #### Testing Suite Analysis
#
# * Comprehensive unit tests
# * Edge case coverage
# * Numerical stability tests
#
# > The implementation builds on established mathematical principles while incorporating modern deep learning practices. The code shows influence from both classical complex analysis and contemporary neural network architectures.
#
# #### The project connects multiple domains:
#
# * Complex analysis
# * Deep learning
# * Quantum computing concepts
# * Signal processing (FFT)
#
#
# #### Key Findings:
# 1. Architecture
# - Well-structured class hierarchy
# - Efficient memory management
# - Clear separation of concerns
#
# 2. Mathematical Implementation
# - Robust complex number operations
# - Stable numerical computations
# - Advanced mathematical functions
#
# 3. Practical Applications
# - Signal processing capabilities
# - Quantum-inspired computations
# - Deep learning integration
#
# 4. Code Quality
# - Comprehensive testing
# - Detailed documentation
# - Production-ready error handling
#
# 5. Innovation Areas
# - Custom autograd implementation
# - Quantum-inspired operations
# - Complex activation functions
#
# > The implementation transforms basic tensor operations into a comprehensive complex number framework, enabling advanced mathematical operations while maintaining gradient computation capabilities.
#
#
# #### The code operates across multiple conceptual dimensions:
#
# - Mathematical (complex plane)
# - Computational (tensor operations)
# - Quantum-inspired (superposition and entanglement)
# - Deep learning (gradients and backpropagation)
#
#
# #### Core strengths:
# 1. Mathematical rigor
# 2. Practical usability
# 3. Performance optimization
# 4. Extensibility
# 5. Robust testing
#
# #### Areas for potential enhancement:
#
# - GPU optimization
# - Additional quantum-inspired operations
# - More advanced complex activation functions
#
#
# **more complextensor analysis will be added <<<<<**
#
#
# # Introduction to Bluecow009's "demon mathematics"
# <details>
#   <summary>author's note</summary>
# Hi. I'm bluecow009, I used to be fully anonymous but now you can know a lot about me in a podcast I did. I don't care about anonymity anymore as I rather help make a better world. The trade-off between doxxing and helping save the planet by inducing a new type of energy usage into the competitive computing industry is worth it. Also, I liked doing a podcast, so please invite me over. you can contact me on twitter/X @bluecow009 or my public email 0xbluecow@protonmail.com, I check it everyday.
# </details>
#
# Since some of these mathematical ideas were discovered by me influenced by everything I learned, we shall call it **"demon mathematics"** later you will understand why.
#
# #### Demon Mathematics - easy mode.
#
# To introduce Demon Mathematics, we have to go back to Bluecow009's first ever release, SuperPrompt. Let us analyse some of the equations used.
#
# **Quantum Wave Function:**
#
# Ψ(x₁, x₂, ..., xₙ, t) = ∑ᵢ αᵢφᵢ(x₁, x₂, ..., xₙ)e^(-iEᵢt/ℏ)
#
# I carefully designed this equation for the `<dreamscape>` tag in the SuperPrompt. While these ideas already existed, its confirmed that the repository for SuperPrompt was the first to use this specific combination of equations. Its important for many to understand that we are doing something new here.
#
# here is how the full tag looks like:
#
# ```xml
# <dreamscape>
# Ψ(x₁, x₂, ..., xₙ, t) = ∑ᵢ αᵢφᵢ(x₁, x₂, ..., xₙ)e^(-iEᵢt/ℏ)
#
# lim_{n→∞} ∫...∫ |Ψ|² dx₁dx₂...dxₙ = 1
#
# ∇ × (∇ × Ψ) = -∇²Ψ + ∇(∇ · Ψ)
# </dreamscape>
# ```
#
# I explained once in a podcast how I arrived at these ideas, basically we wanted to give the LLM a place to "dream" and it worked, at certain point.
#
# > This equation is perfectly suited for ComplexTensor as it involves:
# - Complex exponentials
# - Time evolution
# - Multiple dimensions
# - Superposition of states
#
# The next important equation found on the SuperPrompt is:
#
# **Vector Field Identity:**
#
# ∇ × (∇ × Ψ) = -∇²Ψ + ∇(∇ · Ψ)
#
# We will explore these to the best of our abilities. Implementing these quantum mechanical equations using ComplexTensor enables a bridge between classical tensor operations and quantum mechanics simulations.
#
#
# ### Most Promising Equations for Implementation:
#
# 1. Quantum Wave Function (Implemented above)
#
# - Time evolution of quantum states
# - Multiple dimensions support
# - Probability density calculations
#
#
# 2. Vector Field Operations
#
# - Complex electromagnetic field simulations
# - Curl and divergence operations
# - Laplacian computations
#
#
# 3. Potential Future Implementations:
#
# - f(x) ↔ f(f(...f(x)...)) for iterative complex mappings
# - ∫∫∫∫ dX ∧ dY ∧ dZ ∧ dT for complex space-time integration
#
# > The implementation demonstrates that ComplexTensor can be extended to handle sophisticated quantum mechanical calculations while maintaining numerical stability and gradient computation capabilities. It successfully shows how ComplexTensor can be used for quantum mechanical simulations while maintaining its core features and stability.

# %% [markdown]
# *I created a comprehensive implementation combining quantum wave functions and electromagnetic field operations, complete with testing and logging capabilities.*
#
# code below.

# %%
# quantum_em_mis_core.py

import torch
import torch.nn.functional as F
from complextensor import ComplexTensor
import numpy as np
from numpy.polynomial.hermite import Hermite
import logging
from typing import List, Tuple, Optional, Union
from datetime import datetime

# Configure logging
logging.basicConfig(
    filename=f'quantum_em_mis_core_{datetime.now().strftime("%Y%m%d_%H%M%S")}.log',
    level=logging.INFO,
    format='%(asctime)s - %(name)s - %(levelname)s - %(message)s'
)
logger = logging.getLogger(__name__)


# Suppress ALL loggers related to ComplexTensor
for logger_name in logging.Logger.manager.loggerDict.keys():
    if isinstance(logger_name, str) and 'complextensor' in logger_name.lower():
        logging.getLogger(logger_name).setLevel(logging.CRITICAL)

class MISTransform:
    """Morphing Infinity Spiral Transform implementation."""
    def __init__(self, alpha: complex = 1.0, beta: complex = 2.0):
        self.alpha = alpha
        self.beta = beta
        logger.debug(f"Initialized MISTransform with alpha={alpha}, beta={beta}")

    def complex_power(self, z: ComplexTensor, exponent: float) -> ComplexTensor:
        """Compute z^exponent using exp(log) method."""
        if not isinstance(z, ComplexTensor):
            raise TypeError("Input must be a ComplexTensor")

        log_z = ComplexTensor(
            torch.log(z.abs() + 1e-10),
            z.angle()
        )
        exponent_tensor = ComplexTensor(
            torch.full_like(z.real, exponent),
            torch.zeros_like(z.imag)
        )
        return (log_z * exponent_tensor).exp()

    def __call__(self, z: ComplexTensor, t: float) -> ComplexTensor:
        """Apply MIS transformation."""
        try:
            power_term = self.complex_power(z, float(self.alpha.real))

            log_z = ComplexTensor(
                torch.log(z.abs() + 1e-10),
                z.angle()
            )
            log_z_beta = self.complex_power(log_z, float(self.beta.real))

            phase_tensor = ComplexTensor(
                torch.full_like(z.real, t),
                torch.zeros_like(z.imag)
            )
            rotation = (log_z_beta * phase_tensor).imag

            rotation_term = ComplexTensor(
                torch.cos(rotation),
                torch.sin(rotation)
            )

            return power_term * rotation_term

        except Exception as e:
            logger.error(f"Error in MIS transformation: {str(e)}")
            raise

class EnhancedQuantumWaveFunction:
    """Quantum wave function with MIS scale invariance."""
    def __init__(self, n_states: int, n_dimensions: int, alpha: complex = 1.0, beta: complex = 2.0):
        self.n_states = n_states
        self.n_dimensions = n_dimensions
        self.mis = MISTransform(alpha, beta)

        try:
            self.alphas = ComplexTensor(
                torch.randn(n_states, 1, 1) / np.sqrt(n_states),
                torch.randn(n_states, 1, 1) / np.sqrt(n_states)
            )
            self.energies = torch.linspace(0, 10, n_states).pow(2)

            self.basis = [
                lambda x, n=n: ComplexTensor(
                    torch.exp(-x**2/2) * torch.from_numpy(
                        Hermite.basis(n)(x.cpu().numpy())
                    ).to(x.device).to(torch.float32),
                    torch.zeros_like(x, dtype=torch.float32)
                ) for n in range(n_states)
            ]
            logger.info(f"Initialized QuantumWaveFunction with {n_states} states in {n_dimensions}D")
        except Exception as e:
            logger.error(f"Error initializing QuantumWaveFunction: {str(e)}")
            raise

    def evolve_unnormalized(self, coordinates: List[torch.Tensor], time: float,
                           hbar: float = 1.0) -> ComplexTensor:
        """Evolve quantum state without normalization."""
        try:
            psi = ComplexTensor(
                torch.zeros_like(coordinates[0], dtype=torch.float32),
                torch.zeros_like(coordinates[0], dtype=torch.float32)
            )

            for i in range(self.n_states):
                phi = self.basis[i](coordinates[0])
                for d in range(1, self.n_dimensions):
                    phi = phi * self.basis[i](coordinates[d])

                phi_transformed = self.mis(phi, time)

                phase = -self.energies[i] * time / hbar
                time_evolution = ComplexTensor(
                    torch.cos(phase).view(1, 1).to(torch.float32),
                    -torch.sin(phase).view(1, 1).to(torch.float32)
                )

                psi += self.alphas[i:i+1] * phi_transformed * time_evolution

            return psi

        except Exception as e:
            logger.error(f"Error in quantum evolution: {str(e)}")
            raise

    def get_relative_phases(self, psi: ComplexTensor) -> ComplexTensor:
        """Track relative phases explicitly."""
        if not isinstance(psi, ComplexTensor):
            raise TypeError("Input must be a ComplexTensor")

        reference_phase = psi.angle()[0,0]
        return ComplexTensor(psi.abs(), psi.angle() - reference_phase)

    def measure(self, psi: ComplexTensor) -> torch.Tensor:
        """Lazy normalization only during measurement."""
        if not isinstance(psi, ComplexTensor):
            raise TypeError("Input must be a ComplexTensor")

        prob = psi.abs().pow(2)
        return prob / (prob.sum() + 1e-10)

class EnhancedEMField:
    """EM field with MIS scale invariance."""
    def __init__(self, grid_size: int, dx: float = 0.1, alpha: complex = 1.0, beta: complex = 2.0):
        if grid_size <= 0 or dx <= 0:
            raise ValueError("grid_size and dx must be positive")

        self.grid_size = grid_size
        self.dx = dx
        self.mis = MISTransform(alpha, beta)
        logger.info(f"Initialized EM Field with grid_size={grid_size}, dx={dx}")

    def gradient(self, field: ComplexTensor) -> List[ComplexTensor]:
        """Compute gradient with central differences."""
        if not isinstance(field, ComplexTensor):
            raise TypeError("Input must be a ComplexTensor")

        try:
            grad = []
            for axis in range(field.real.ndim):
                grad_real = torch.zeros_like(field.real)
                grad_imag = torch.zeros_like(field.imag)

                slices = [slice(None)] * field.real.ndim
                slices_fwd = [slice(None)] * field.real.ndim
                slices_bwd = [slice(None)] * field.real.ndim

                slices[axis] = slice(1, -1)
                slices_fwd[axis] = slice(2, None)
                slices_bwd[axis] = slice(0, -2)

                grad_real[tuple(slices)] = (
                    field.real[tuple(slices_fwd)] - field.real[tuple(slices_bwd)]
                ) / (2 * self.dx)
                grad_imag[tuple(slices)] = (
                    field.imag[tuple(slices_fwd)] - field.imag[tuple(slices_bwd)]
                ) / (2 * self.dx)

                grad.append(ComplexTensor(grad_real, grad_imag))

            return grad

        except Exception as e:
            logger.error(f"Error computing gradient: {str(e)}")
            raise

    def divergence(self, field_components: List[ComplexTensor]) -> ComplexTensor:
        """Compute divergence."""
        if not isinstance(field_components, list) or not all(isinstance(f, ComplexTensor) for f in field_components):
            raise TypeError("Input must be a list of ComplexTensors")

        try:
            div = ComplexTensor(
                torch.zeros_like(field_components[0].real),
                torch.zeros_like(field_components[0].imag)
            )

            for component, field in enumerate(field_components):
                transformed_field = self.mis(field, 0.0)
                grad = self.gradient(transformed_field)[component]
                div += grad

            return div

        except Exception as e:
            logger.error(f"Error computing divergence: {str(e)}")
            raise

    def curl(self, field_components: List[ComplexTensor]) -> List[ComplexTensor]:
        """Compute curl."""
        if len(field_components) != 3:
            raise ValueError("Curl requires exactly 3 field components")

        try:
            transformed_fields = [self.mis(f, 0.0) for f in field_components]
            gradients = [self.gradient(f) for f in transformed_fields]

            curl_x = gradients[2][1] - gradients[1][2]
            curl_y = gradients[0][2] - gradients[2][0]
            curl_z = gradients[1][0] - gradients[0][1]

            return [curl_x, curl_y, curl_z]

        except Exception as e:
            logger.error(f"Error computing curl: {str(e)}")
            raise

# Initialization check
if __name__ == "__main__":
    logger.info("quantum_em_mis_core initialized")

# %% [markdown]
# **We will for now:**
#
# 1. Keep states unnormalized during evolution
# 2. Implement lazy normalization for measurements
# 3. Track relative phases explicitly
# 4. Use logarithmic representation for large magnitudes

# %% [markdown]
# *And now you can run a comprehensive test suite that will output raw .npy data for analysis.*

# %%
# quantum_em_mis_tests.py

import torch
import numpy as np
from datetime import datetime
import logging
import unittest
import time
import psutil
from pathlib import Path
import json
from typing import List, Tuple, Dict, Any
from complextensor import ComplexTensor
# from quantum_em_mis_core import MISTransform, EnhancedQuantumWaveFunction, EnhancedEMField

# Configure logging
logging.basicConfig(
    filename=f'quantum_em_mis_tests_{datetime.now().strftime("%Y%m%d_%H%M%S")}.log',
    level=logging.INFO,
    format='%(asctime)s - %(name)s - %(levelname)s - %(message)s'
)
logger = logging.getLogger(__name__)

class DataCollector:
    """Collect and save test data."""
    def __init__(self):
        self.timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
        self.data_dir = Path(f"test_data_{self.timestamp}")
        self.data_dir.mkdir(exist_ok=True)
        self.metadata = {
            "timestamp": self.timestamp,
            "data_files": []
        }

    def save_tensor_data(self, data: torch.Tensor, name: str, metadata: Dict = None):
        """Save tensor data with metadata."""
        file_path = self.data_dir / f"{name}.npy"
        np.save(file_path, data.detach().cpu().numpy())

        meta_info = {
            "filename": f"{name}.npy",
            "shape": list(data.shape),
            "dtype": str(data.dtype),
            "metadata": metadata or {}
        }
        self.metadata["data_files"].append(meta_info)

    def save_complex_tensor_data(self, data: ComplexTensor, name: str, metadata: Dict = None):
        """Save ComplexTensor data."""
        self.save_tensor_data(data.real, f"{name}_real", metadata)
        self.save_tensor_data(data.imag, f"{name}_imag", metadata)

    def log_performance(self, name: str, execution_time: float, memory_used: float):
        """Log performance metrics."""
        with open(self.data_dir / "performance.json", "a") as f:
            json.dump({
                "name": name,
                "time": execution_time,
                "memory_mb": memory_used,
                "timestamp": datetime.now().isoformat()
            }, f)
            f.write('\n')

    def save_metadata(self):
        """Save collected metadata."""
        with open(self.data_dir / "metadata.json", "w") as f:
            json.dump(self.metadata, f, indent=2)

class QuantumEMMISTests(unittest.TestCase):
    def setUp(self):
        self.data_collector = DataCollector()

    def tearDown(self):
        self.data_collector.save_metadata()

    def measure_performance(self, name: str, callable_obj, *args, **kwargs):
        """Measure performance and collect data."""
        process = psutil.Process()
        start_mem = process.memory_info().rss / 1024 / 1024
        start_time = time.time()

        result = callable_obj(*args, **kwargs)

        end_time = time.time()
        end_mem = process.memory_info().rss / 1024 / 1024

        execution_time = end_time - start_time
        memory_used = end_mem - start_mem

        self.data_collector.log_performance(name, execution_time, memory_used)
        return result

    def test_mis_scale_invariance(self):
        """Test MIS transformation scale invariance."""
        logger.info("Testing MIS scale invariance")
        mis = MISTransform()
        scales = [0.1, 1.0, 10.0]

        x = torch.linspace(-5, 5, 50)
        X, Y = torch.meshgrid(x, x, indexing='ij')
        Z = ComplexTensor(X.unsqueeze(0), Y.unsqueeze(0))

        for scale in scales:
            scaled_Z = ComplexTensor(Z.real * scale, Z.imag * scale)
            transformed = self.measure_performance(
                f"mis_transform_scale_{scale}",
                mis.__call__,
                scaled_Z, t=1.0
            )
            self.data_collector.save_complex_tensor_data(
                transformed,
                f"mis_scale_{scale}",
                {"scale": scale}
            )

    def test_quantum_evolution(self):
        """Test quantum wave function evolution."""
        logger.info("Testing quantum evolution")
        qwf = EnhancedQuantumWaveFunction(n_states=3, n_dimensions=2)

        x = torch.linspace(-5, 5, 50)
        X, Y = torch.meshgrid(x, x, indexing='ij')
        X = X.unsqueeze(0)
        Y = Y.unsqueeze(0)

        times = [0.0, 0.5, 1.0, 2.0]

        for t in times:
            psi = self.measure_performance(
                f"quantum_evolution_t_{t}",
                qwf.evolve_unnormalized,
                [X, Y], t
            )
            self.data_collector.save_complex_tensor_data(
                psi,
                f"psi_t_{t}",
                {"time": t}
            )

            prob = qwf.measure(psi)
            self.data_collector.save_tensor_data(
                prob,
                f"probability_t_{t}",
                {"time": t}
            )

            total_prob = prob.sum().item()
            logger.info(f"Total probability at t={t}: {total_prob}")
            self.assertAlmostEqual(total_prob, 1.0, places=5)

    def test_em_field_operations(self):
        """Test electromagnetic field operations."""
        logger.info("Testing EM field operations")
        em = EnhancedEMField(grid_size=50)

        # Create test field
        k = 2 * np.pi / 10
        omega = 2 * np.pi
        x = torch.linspace(-5, 5, 50)
        X, Y, Z = torch.meshgrid(x, x, x, indexing='ij')
        X = X.unsqueeze(0)
        Y = Y.unsqueeze(0)
        Z = Z.unsqueeze(0)

        # Vector potential
        A_amp = 1.0
        A_z = A_amp * torch.cos(k * X)

        # Magnetic field
        B_x = -k * A_amp * torch.sin(k * X)
        B_y = torch.zeros_like(X)
        B_z = torch.zeros_like(X)

        # Electric field
        Ex = ComplexTensor(torch.zeros_like(X), torch.zeros_like(X))
        Ey = ComplexTensor(torch.zeros_like(X), torch.zeros_like(X))
        Ez = ComplexTensor(
            omega * A_amp * torch.sin(k * X),
            torch.zeros_like(X)
        )

        # Save field configurations
        self.data_collector.save_complex_tensor_data(
            Ex, "E_x", {"field": "electric", "component": "x"}
        )
        self.data_collector.save_complex_tensor_data(
            Ey, "E_y", {"field": "electric", "component": "y"}
        )
        self.data_collector.save_complex_tensor_data(
            Ez, "E_z", {"field": "electric", "component": "z"}
        )

        # Test operations
        curl = self.measure_performance(
            "em_curl",
            em.curl,
            [Ex, Ey, Ez]
        )
        for i, component in enumerate(['x', 'y', 'z']):
            self.data_collector.save_complex_tensor_data(
                curl[i],
                f"curl_{component}",
                {"operation": "curl", "component": component}
            )

        div = self.measure_performance(
            "em_divergence",
            em.divergence,
            [Ex, Ey, Ez]
        )
        self.data_collector.save_complex_tensor_data(
            div,
            "divergence",
            {"operation": "divergence"}
        )

        # Verify Maxwell's equations
        div_mean = div.abs().mean().item()
        logger.info(f"Mean divergence: {div_mean}")
        self.assertLess(div_mean, 1e-5)

        # B-field divergence
        B_fields = [
            ComplexTensor(B_x, torch.zeros_like(B_x)),
            ComplexTensor(B_y, torch.zeros_like(B_y)),
            ComplexTensor(B_z, torch.zeros_like(B_z))
        ]
        B_div = self.measure_performance(
            "b_field_divergence",
            em.divergence,
            B_fields
        )
        self.data_collector.save_complex_tensor_data(
            B_div,
            "B_divergence",
            {"operation": "B-field divergence"}
        )

    def test_edge_cases(self):
        """Test behavior at edge cases."""
        logger.info("Testing edge cases")
        mis = MISTransform()

        # Near zero
        x = torch.linspace(-1e-10, 1e-10, 50)
        X, Y = torch.meshgrid(x, x, indexing='ij')
        Z_near_zero = ComplexTensor(X.unsqueeze(0), Y.unsqueeze(0))

        result = self.measure_performance(
            "mis_near_zero",
            mis.__call__,
            Z_near_zero, t=1.0
        )
        self.data_collector.save_complex_tensor_data(
            result,
            "edge_case_near_zero",
            {"case": "near_zero"}
        )

        # Large magnitude
        x = torch.linspace(-1e10, 1e10, 50)
        X, Y = torch.meshgrid(x, x, indexing='ij')
        Z_large = ComplexTensor(X.unsqueeze(0), Y.unsqueeze(0))

        result = self.measure_performance(
            "mis_large_magnitude",
            mis.__call__,
            Z_large, t=1.0
        )
        self.data_collector.save_complex_tensor_data(
            result,
            "edge_case_large_magnitude",
            {"case": "large_magnitude"}
        )

def run_tests():
    """Run all tests and collect data."""
    logger.info("Starting comprehensive test suite")
    suite = unittest.TestLoader().loadTestsFromTestCase(QuantumEMMISTests)
    runner = unittest.TextTestRunner(verbosity=2)
    result = runner.run(suite)
    logger.info("Test suite completed")
    return result

if __name__ == "__main__":
    run_tests()
# Out:
# test_edge_cases (__main__.QuantumEMMISTests)
# Test behavior at edge cases. ... ok
# test_em_field_operations (__main__.QuantumEMMISTests)
# Test electromagnetic field operations. ... ok
# test_mis_scale_invariance (__main__.QuantumEMMISTests)
# Test MIS transformation scale invariance. ... ok
# test_quantum_evolution (__main__.QuantumEMMISTests)
# Test quantum wave function evolution. ... ok
#
# ----------------------------------------------------------------------
# Ran 4 tests in 0.139s
#
# OK

# %% [markdown]
# Now the data should be saved into the /content/ directory if you are using Colab or your root folder in your local machine. in this case /content/test_data_20241027_153512, let us load the new collected data.

# %%
# load the .npy files into the colab
import os
import numpy as np

# Specify the folder path
data_folder = '/content/test_data_20241027_153512'

# Dictionary to hold all loaded .npy data for later use
data_dict = {}

# Load each .npy file into the dictionary
for npy_file in os.listdir(data_folder):
    if npy_file.endswith('.npy'):
        file_path = os.path.join(data_folder, npy_file)
        data_dict[npy_file] = np.load(file_path)

# Now `data_dict` contains all .npy files loaded and can be accessed later

# %% [markdown]
# Now, let us go into some math. We introduce Bluecow009's. Morphing Infinity Spiral. You can read the full math on the [github.](https://github.com/NeoVertex1/MIS)
#
# MIS is truly a new genre of mathematical objects, it has features that few have observed before, a self-similarity, spiraled fractals, scale invariance, the equation also allows for a completely new PDE.
#
# Below is a test that shows the MIS at work, we will delve (🤖) in the math soon.

# %%
import cupy as cp
import numpy as np
from numba import cuda, float64
import math
import warnings
import json
warnings.filterwarnings("ignore", category=RuntimeWarning)

# Set CUDA configuration constants
THREADS_PER_BLOCK = 256

@cuda.jit(device=True)
def complex_exp(real, imag):
    """Device function for complex exponential"""
    if real > 700:  # Prevent exp overflow
        real = 700
    exp_real = math.exp(real)
    return exp_real * math.cos(imag), exp_real * math.sin(imag)

@cuda.jit(device=True)
def complex_mul(a_real, a_imag, b_real, b_imag):
    """Element-wise complex multiplication"""
    return cuda.fma(a_real, b_real, -a_imag * b_imag), cuda.fma(a_real, b_imag, a_imag * b_real)

@cuda.jit(device=True)
def complex_log(real, imag):
    """Device function for complex logarithm"""
    r = math.sqrt(cuda.fma(real, real, imag * imag))
    theta = math.atan2(imag, real)
    return math.log(max(r, 1e-300)), theta  # Prevent log underflow

def preprocess_array(arr):
    """Convert 0-dimensional arrays to 1-dimensional arrays for compatibility."""
    if arr.ndim == 0:
        return np.array([arr.item()])  # Convert 0d to 1d scalar-compatible array
    return arr

@cuda.jit
def mis_kernel(z_real, z_imag, t, alpha_real, alpha_imag, beta_real, beta_imag, out_real, out_imag):
    idx = cuda.grid(1)
    stride = cuda.gridsize(1)

    for i in range(idx, z_real.size, stride):
        z_real_val = z_real[i]
        z_imag_val = z_imag[i]

        r_squared = cuda.fma(z_real_val, z_real_val, z_imag_val * z_imag_val)

        if r_squared < 1e-15:
            out_real[i] = 0.0
            out_imag[i] = 0.0
            continue

        log_z_real, log_z_imag = complex_log(z_real_val, z_imag_val)

        power_term_real = cuda.fma(alpha_real, log_z_real, -alpha_imag * log_z_imag)
        power_term_imag = cuda.fma(alpha_real, log_z_imag, alpha_imag * log_z_real)

        power_real, power_imag = complex_exp(power_term_real, power_term_imag)

        beta_log_real = cuda.fma(beta_real, log_z_real, -beta_imag * log_z_imag)  # Corrected
        beta_log_imag = cuda.fma(beta_real, log_z_imag, beta_imag * log_z_real)  # Corrected

        exp_real, exp_imag = complex_exp(beta_log_real, beta_log_imag)

        cos_phase = math.cos(t * exp_real)
        sin_phase = math.sin(t * exp_real)

        out_real[i], out_imag[i] = complex_mul(power_real, power_imag, cos_phase, sin_phase)

class GPUMorphingInfinitySpiral:
    def __init__(self, alpha=0.5+0.5j, beta=1+0j, num_points=10000):
        self.alpha = complex(alpha)
        self.beta = complex(beta)
        self.num_points = num_points
        try:
            self.stream = cp.cuda.Stream()
            self.mem_pool = cp.cuda.MemoryPool()
            cp.cuda.set_allocator(self.mem_pool.malloc)
        except Exception as e:
            raise RuntimeError(f"CUDA initialization failed: {e}")

    def _calculate_grid_dimensions(self, size):
        threads_per_block = THREADS_PER_BLOCK
        blocks = max(32, (size + threads_per_block - 1) // threads_per_block)
        return blocks, threads_per_block

    def mis(self, z, t):
        """MIS transformation with data saving"""
        try:
            # Preprocess arrays to ensure no 0-dimensional values are passed to kernel
            z = preprocess_array(cp.array(z, dtype=cp.complex128))
            t = float(t)
            z_real = cp.real(z).astype(cp.float64)
            z_imag = cp.imag(z).astype(cp.float64)
            out_real = cp.zeros_like(z_real)
            out_imag = cp.zeros_like(z_imag)
            blocks, threads_per_block = self._calculate_grid_dimensions(z_real.size)

            with self.stream:
                mis_kernel[blocks, threads_per_block](
                    z_real, z_imag, t,
                    self.alpha.real, self.alpha.imag,
                    self.beta.real, self.beta.imag,
                    out_real, out_imag
                )
                self.stream.synchronize()

            result = out_real + 1j * out_imag
            self._save_data(result, z, t)
            return result

        except Exception as e:
            raise RuntimeError(f"Error in MIS computation: {e}")

    def _save_data(self, result, z, t):
        """Save output to JSON for further historical analysis and data evaluation"""
        data = {
            "input": {
                "z_real": z.real.tolist(),
                "z_imag": z.imag.tolist(),
                "t": t
            },
            "output": {
                "result_real": result.real.tolist(),
                "result_imag": result.imag.tolist()
            },
            "historical_context": {
                "scientific_foundation": "Quantum-inspired computation",
                "objective": "Data collection for sustainability frameworks",
                "emergent_patterns": "Self-organizing fractal structures"
            }
        }
        with open("mis_data_output.json", "w") as file:
            json.dump(data, file, indent=4)

def main():
    """Main function with data output, historical analysis, and JSON saving"""
    try:
        device = cp.cuda.Device(0)
        device.use()

        print("\nCUDA Device Information:")
        props = cp.cuda.runtime.getDeviceProperties(0)
        print(f"Device: {props['name'].decode()}")
        print(f"Compute Capability: {props['major']}.{props['minor']}")
        print(f"Total Memory: {props['totalGlobalMem']/1024**3:.2f} GB")
        print(f"Max Threads Per Block: {props['maxThreadsPerBlock']}")

        mis = GPUMorphingInfinitySpiral(alpha=0.5+0.5j, beta=1+0j)
        print("\nRunning comprehensive tests...")

        # Test basic MIS function and save results to JSON
        test_points = [1+1j, 2+3j, 0.5-0.5j]
        for z in test_points:
            for t in [0, 1, 10]:
                result = mis.mis(z, t)
                print(f"mis({z}, {t}) = {result}")

    except Exception as e:
        print(f"An error occurred: {e}")

    finally:
        # Cleanup
        try:
            cp.cuda.Stream.null.synchronize()
            mempool = cp.get_default_memory_pool()
            pinned_mempool = cp.get_default_pinned_memory_pool()
            mempool.free_all_blocks()
            pinned_mempool.free_all_blocks()
        except Exception as e:
            print(f"Error during cleanup: {e}")

if __name__ == "__main__":
    main()
# Out:
# CUDA Device Information:
# Device: Tesla T4
# Compute Capability: 7.5
# Total Memory: 14.75 GB
# Max Threads Per Block: 1024
#
# Running comprehensive tests...
# /usr/local/lib/python3.10/dist-packages/numba/cuda/dispatcher.py:536: NumbaPerformanceWarning: Grid size 32 will likely result in GPU under-utilization due to low occupancy.
#   warn(NumbaPerformanceWarning(msg))
# mis((1+1j), 0) = [0.67777251+0.43060227j]
# mis((1+1j), 1) = [0.00386273+0.8029813j]
# mis((1+1j), 10) = [-0.33444289-0.73002866j]
# mis((2+3j), 0) = [0.49285967+1.05191138j]
# mis((2+3j), 1) = [-1.16160231+0.01040644j]
# mis((2+3j), 10) = [-0.75921031+0.87922006j]
# mis((0.5-0.5j), 0) = [1.05114599-0.66781383j]
# mis((0.5-0.5j), 1) = [1.24263439-0.08211554j]
# mis((0.5-0.5j), 10) = [-0.34221252-1.19740293j]

# %%
import numpy as np
# from your_module import GPUMorphingInfinitySpiral  # Import the MIS class from your existing code

# Massive configurations for alpha and beta sweeps
alpha_range = np.linspace(-1-1j, 1+1j, num=5)  # Alpha sweep from -1-1j to 1+1j
beta_range = np.linspace(-1-1j, 1+1j, num=5)   # Beta sweep from -1-1j to 1+1j

# High-resolution time points for in-depth analysis
time_points_massive = [0, 0.25, 0.5, 1, 2, 5, 10, 20]

# Grid of complex test points
z_real_range = np.linspace(-2, 2, num=5)
z_imag_range = np.linspace(-2, 2, num=5)
test_points_massive = [complex(r, i) for r in z_real_range for i in z_imag_range]

# Initialize dictionary to store raw output data for massive analysis
massive_results_summary = {}

# Loop through each alpha and beta configuration
for alpha in alpha_range:
    for beta in beta_range:
        # Initialize the MIS system with the current alpha and beta
        mis_system = GPUMorphingInfinitySpiral(alpha=alpha, beta=beta)

        # Print configuration details for clarity
        print(f"\nTesting with alpha={alpha} and beta={beta}\n")

        # Store results for this configuration
        massive_results_summary[(alpha, beta)] = {}

        # Loop through each test point and calculate MIS over high-resolution time points
        for z in test_points_massive:
            results = []
            for t in time_points_massive:
                try:
                    # Run MIS computation
                    result = mis_system.mis(z, t)

                    # Ensure result is converted to host array for compatibility
                    if isinstance(result, cp.ndarray):
                        result = result.get()  # Move to host if on GPU

                    results.append(result[0] if len(result) == 1 else result)  # Extract single result if array
                except (RuntimeError, ValueError, cuda.CUDARuntimeError) as e:
                    # Handle any computation or data retrieval error gracefully
                    print(f"Error for input z={z}, t={t}, alpha={alpha}, beta={beta}: {e}")
                    results.append(np.nan)  # Record NaN for any computation error

            # Print raw data for each (alpha, beta, z) configuration
            print(f"Results for input {z}:")
            for t, res in zip(time_points_massive, results):
                print(f"t={t}: {res}")
            print()  # Newline for better readability

            # Store raw results in summary dictionary
            massive_results_summary[(alpha, beta)][z] = results

# Output the entire raw data structure for all configurations
print("\nComplete massive results summary:")
for (alpha, beta), test_results in massive_results_summary.items():
    print(f"Configuration alpha={alpha}, beta={beta}")
    for z, results in test_results.items():
        print(f"Input {z}: {results}")
    print()  # Newline for better readability
# Out:
# Streaming output truncated to the last 5000 lines.
# t=20: (0.4906790586001118+0.5091503328598618j)
#
# Results for input (2+1j):
# t=0: (0.6792552025237488-0.49962040369354166j)
# t=0.25: (0.7817468692349652-0.3160379888301511j)
# t=0.5: (0.835633301946581-0.11280586252642529j)
# t=1: (0.7874192253226351+0.3016274880291547j)
# t=2: (0.17163364372969916+0.8255604582842757j)
# t=5: (-0.2864191179835809-0.7930777180049785j)
# t=10: (-0.8417477484550933+0.04968808623058067j)
# t=20: (0.7333179382620034+0.4162366867127897j)
#
# Results for input (2+2j):
# t=0: (0.5386781752670272-0.6966113851711j)
# t=0.25: (0.6942763900737541-0.5416843108722729j)
# t=0.5: (0.8067078616187435-0.3530779297287313j)
# t=1: (0.8772273285259352+0.07690131693452187j)
# t=2: (0.40925772147919454+0.7797113028991376j)
# t=5: (-0.5151949387896934-0.7141538864309965j)
# t=10: (-0.8309608198203823+0.2914544808069536j)
# t=20: (0.8557929561115941+0.2075090714373517j)
#
#
# Testing with alpha=(-0.5-0.5j) and beta=(0.5+0.5j)
#
# Results for input (-2-2j):
# t=0: (0.1448112796304857+0.1119801908639111j)
# t=0.25: (-0.03057363887770524+0.18048579572895024j)
# t=0.5: (-0.17361215361057925+0.05804041671829488j)
# t=1: (0.048350437454982895-0.1765562376469562j)
# t=2: (-0.18165965753168606+0.02257517839591141j)
# t=5: (-0.17621114701392507-0.04959336167445771j)
# t=10: (0.1819597664578597-0.020012827005144857j)
# t=20: (0.11701182909875524-0.1407767797085172j)
#
# Results for input (-2-1j):
# t=0: (0.10386087785601013+0.1412032837346879j)
# t=0.25: (-0.036692619071366894+0.17140332841623407j)
# t=0.5: (-0.15256499925753275+0.08630973460756824j)
# t=1: (-0.06753066208520984-0.16175617133455228j)
# t=2: (0.027371077998932132+0.17313657434423324j)
# t=5: (0.09300520425602657-0.14857819916722173j)
# t=10: (-0.17239239101970213-0.031722433781000314j)
# t=20: (0.1473220970471095-0.09498236156319703j)
#
# Results for input (-2+0j):
# t=0: (-1.1554189343197967-3.1992738867757065j)
# t=0.25: (-1.2349207555088997-3.169434814600698j)
# Results for input (-1+2j):
# t=0: (0.2785925910875181-1.8282983689389474j)
# t=0.25: (0.31576233085455346-1.8222466649954314j)
# t=0.5: (0.35280114069969515-1.8154393718311461j)
# t=1: (0.42642459914785485-1.7995696204690896j)
# t=2: (0.5714290219911671-1.7589080790365057j)
# t=5: (0.9799934943831654-1.5684073159228586j)
# t=10: (1.521082548661832-1.0519489711150904j)
# t=20: (1.8089738046094188+0.3845809822528884j)
#
# Results for input -2j:
# t=0: (0.2918503793793073+0.13697862691506052j)
# t=0.25: (0.13439843728434106+0.293047518725049j)
# t=0.5: (-0.08660469060723253+0.3105469622137793j)
# t=1: (-0.3206176010732326-0.033825168993316286j)
# t=2: (0.31400950320571874-0.07306038647501566j)
# t=5: (-0.10783554888454705+0.30382771857114915j)
# t=10: (-0.3129030626131561-0.07766248504064419j)
# t=20: (0.32202958068759047+0.015386271073771695j)
#
# Results for input -1j:
# t=0: (0.3223969419448345+0.3223969419448344j)
# t=0.25: (0.17657480833272243+0.42035807761124827j)
# t=0.5: (0.004539502573585043+0.4559155286532214j)
# t=1: (-0.31591351568568615+0.32875253148511524j)
# t=2: (-0.33497776419046155-0.3093048235135066j)
# t=5: (-0.2887535983793582+0.3528469013236962j)
# t=10: (-0.3798018656564331-0.25225011237788314j)
# t=20: (0.4221961022731471+0.17213374909100254j)
#
# Results for input 0j:
# t=0: 0j
# t=0.25: 0j
# t=0.5: 0j
# t=1: 0j
# t=2: 0j
# t=5: 0j
# t=10: 0j
# t=20: 0j
#
# Results for input 1j:
# t=0: (1.5508831969180257-1.5508831969180255j)
# t=0.25: (1.6707131768366983-1.4209837654630604j)
# t=0.5: (1.779695682620224-1.2818582832077365j)
# t=1: (1.96236292369285-0.9795964152042415j)
# t=2: (2.171635649850247-0.30736946052730507j)
# t=5: (1.4857075483870683+1.6134281705830718j)
# t=10: (-1.6732363779044366+1.418011778731965j)
# t=20: (1.7842415107922833-1.2755232699292558j)
#
# Results for input 2j:
# t=0: (0.6589325864505904-1.4039396486303144j)
# t=0.25: (0.7534674412297491-1.3555535789814324j)
# t=0.5: (0.8444693227996081-1.3008113826889152j)
# t=1: (1.0141859189673212-1.1733139444543756j)
# t=2: (1.2937968617957158-0.8551773914751448j)
# t=5: (1.507233822174804+0.36535584814671634j)
# t=10: (-0.05706652976526056+1.5498329270160789j)
# t=20: (-0.5538990766750306-1.44859742625107j)
#
# Results for input (1-2j):
# t=0: (0.3800658903778174+0.0579137098097343j)
# t=0.25: (0.26948192320258546+0.27419622878450584j)
# t=0.5: (0.05131429332276148+0.38101302092368816j)
# t=1: (-0.351202438511024+0.1563998912931836j)
# t=2: (0.21122279328749777-0.32123046307664566j)
# t=5: (0.3475180537117878+0.16442408934514496j)
# t=10: (0.28580625668510945+0.2571358832451328j)
# t=20: (0.09761921521053149+0.3718528843968931j)
#
# Results for input (1-1j):
# t=0: (0.5541873876786361+0.12358511756179853j)
# t=0.25: (0.4523076011520392+0.3432415707412525j)
# t=0.5: (0.2681748854826646+0.5004789433544573j)
# t=1: (-0.20404134708045124+0.5298717492246867j)
# t=2: (-0.49394540757760497-0.280026563521799j)
# t=5: (-0.4652118433000613+0.3255378362006383j)
# t=10: (0.07374750162235277-0.5629904510285193j)
# t=20: (-0.5673208378201157-0.02332399879772819j)
#
# Results for input (1+0j):
# t=0: (1+0j)
# t=0.25: (0.9689124217106447+0.24740395925452294j)
# t=0.5: (0.8775825618903728+0.479425538604203j)
# t=1: (0.5403023058681398+0.8414709848078965j)
# t=2: (-0.4161468365471424+0.9092974268256817j)
# t=5: (0.2836621854632263-0.9589242746631385j)
# t=10: (-0.8390715290764524-0.5440211108893699j)
# t=20: (0.40808206181339196+0.9129452507276277j)
#
# Results for input (1+1j):
# t=0: (1.0511459897104245-0.6678138252789602j)
# t=0.25: (1.1487081135458623-0.48099154544745537j)
# t=0.5: (1.2133685427941252-0.28039253962202054j)
# t=1: (1.237571640208323+0.13892311639934593j)
# t=2: (0.8769198903599145+0.8842481002576037j)
# t=5: (-1.182627234004103+0.3902256043749941j)
# t=10: (1.242167499783985-0.08889937794174105j)
# t=20: (1.1355340071297488+0.5113176268914278j)
#
# Results for input (1+2j):
# t=0: (0.6710143779266006-0.9502012076895322j)
# t=0.25: (0.7833625255241685-0.8599335928333447j)
# t=0.5: (0.8836862846073066-0.7564662456949435j)
# t=1: (1.0423090828616073-0.5164633639117719j)
# t=2: (1.162499039246941+0.04169669325986608j)
# t=5: (0.05495877069254191+1.1619475736894642j)
# t=10: (-0.757704902570151-0.8826244451067657j)
# t=20: (-1.040856267787931+0.5193850789976999j)
#
# Results for input (2-2j):
# t=0: (0.398253576701631-0.05091718390460472j)
# t=0.25: (0.35416109407268015+0.18912532992082104j)
# t=0.5: (0.17920230728310022+0.3592840158382092j)
# t=1: (-0.2802496734396586+0.2875040721613903j)
# t=2: (0.04072495703677343-0.3994245220899315j)
# t=5: (0.3784262865614931-0.1341343230187409j)
# t=10: (0.3414189052628646-0.21126192771421048j)
# t=20: (0.22328790993791414-0.33367795888846946j)
#
# Results for input (2-1j):
# t=0: (0.5226749470359452-0.0900089801468423j)
# t=0.25: (0.5076120930140785+0.1536902072090777j)
# t=0.5: (0.38496696245502554+0.36481660404133714j)
# t=1: (-0.061805656541546655+0.5267549502240783j)
# t=2: (-0.4876438722444276-0.20855256082954993j)
# t=5: (-0.5059445376928743+0.15909381365988584j)
# t=10: (0.4801262141326281-0.2253209605624219j)
# t=20: (0.40323575702158576-0.34451653229610246j)
#
# Results for input (2+0j):
# t=0: (0.6650637002129894-0.24018799857404816j)
# t=0.25: (0.7070370720447731-0.00992868341496255j)
# t=0.5: (0.6715458839296837+0.2214184404630741j)
# t=1: (0.391784961102035+0.5886463660418512j)
# t=2: (-0.478297986059505+0.5207984605693661j)
# t=5: (0.7069526745393162+0.01476197689022881j)
# t=10: (0.6544575621206049+0.2677411051429247j)
# t=20: (0.3060145867210354+0.6374598596883995j)
#
# Results for input (2+1j):
# t=0: (0.6792552025237488-0.49962040369354166j)
# t=0.25: (0.7781697279062905-0.3247461354854378j)
# t=0.5: (0.8329062896292373-0.13143549991738795j)
# t=1: (0.8001000587527098+0.2661730150229109j)
# t=2: (0.24458902193187176+0.8069599669704111j)
# t=5: (-0.45493083466696144-0.7099620508250412j)
# t=10: (-0.7377331568221156+0.40836009509714877j)
# t=20: (0.7840214144590776-0.31035237974287194j)
#
# Results for input (2+2j):
# t=0: (0.5386781752670272-0.6966113851711j)
# t=0.25: (0.6509471561828274-0.5930509238813328j)
# t=0.5: (0.7436324483759257-0.4716485769950323j)
# t=1: (0.8597713139141947-0.19035463280223053j)
# t=2: (0.782383153423676+0.40412646498074994j)
# t=5: (-0.7362013996716097+0.4831657040608073j)
# t=10: (0.8534299212150095-0.21702296660481654j)
# t=20: (0.8060120939196757+0.35466336562187045j)
#
#
# Testing with alpha=(-0.5-0.5j) and beta=(1+1j)
#
# Results for input (-2-2j):
# t=0: (0.1448112796304857+0.1119801908639111j)
# t=0.25: (-0.15042173546990045+0.10432243935203957j)
# t=0.5: (-0.05412949324798164-0.1748710033563409j)
# t=1: (-0.05622449196107871+0.17420871493084175j)
# t=2: (-0.18295208459887025+0.006197144105513792j)
# t=5: (0.1607536474013617+0.08756788624430399j)
# t=10: (0.1726178183836482+0.060934051486886395j)
# t=20: (0.1830187267776566+0.0037437284653366143j)
#
# Results for input (-2-1j):
# t=0: (0.10386087785601013+0.1412032837346879j)
# t=0.25: (0.01470790850144092-0.17466861971743255j)
# t=0.5: (-0.12601093355421747+0.12184701026809978j)
# t=1: (-0.13763493791606884-0.10854525853909835j)
# t=2: (0.16152167374862106+0.06808963354229378j)
# t=5: (-0.16092947995224172+0.06947770699138588j)
# t=10: (-0.03154138789771456-0.17242560754124006j)
# t=20: (-0.0471478213390305+0.16882692981116104j)
#
# Results for input (-2+0j):
# t=0: (-1.1554189343197967-3.1992738867757065j)
# t=0.25: (-1.2084317492820589-3.1796287556437672j)
# t=0.5: (-1.2611107368997552-3.1591052571362335j)
# t=1: (-1.3654091163953739-3.115446077410751j)
# t=2: (-1.5693663087426766-3.01785283030386j)
# t=5: (-2.136185241758405-2.6470849871666786j)
# t=10: (-2.8830647050050677-1.805071805536742j)
# t=20: (-3.382626620066719+0.35802718556784885j)
#
# Results for input (-2+1j):
# t=0: (-0.4329861630801441-2.514316010313677j)
# t=0.25: (-0.5236870165075714-2.497000986359427j)
# t=0.5: (-0.6137018945204388-2.4764151513428794j)
# t=1: (-0.7912031368722692-2.425543158416694j)
# t=2: (-1.1328649493536815-2.2860181590845756j)
# t=5: (-1.9896491194118269-1.5970467741310188j)
# t=10: (-2.5484457273443195+0.12118742475618509j)
# t=20: (-0.19244298321331976+2.5440573333457936j)
#
# Results for input (-2+2j):
# t=0: (-0.24493596147555394-1.9157898226117454j)
# t=0.25: (-0.3685995092518263-1.8958846672268885j)
# t=0.5: (-0.4907127787902314-1.8680056847822135j)
# t=1: (-0.7282427978333502-1.7888283028425482j)
# t=2: (-1.1628006368499635-1.5421215738676428j)
# t=5: (-1.9107358838982094-0.2816605255097449j)
# t=10: (-0.7873166290849282+1.7636260361009197j)
# t=20: (1.5897850701841612-1.0967350182547462j)
#
# Results for input (-1-2j):
# t=0: (0.1975274245024823+0.13949018460865176j)
# t=0.25: (-0.1104109788308761+0.21513719061647016j)
# t=0.5: (-0.22849494050127797-0.07914958747875467j)
# t=1: (0.2414876257743346+0.012582592364632918j)
# t=2: (0.21095457833132208-0.11820643347040673j)
# t=5: (-0.14214479824176146-0.1956257942234319j)
# t=10: (0.07164587785272808+0.23095770872489094j)
# t=20: (-0.08390195024612632+0.2267929844100918j)
#
# Results for input (-1-1j):
# t=0: (0.138824855080172+0.21851178302380536j)
# t=0.25: (0.2165335728638591-0.14189063228798854j)
# t=0.5: (-0.14492822539022693-0.2145123520767812j)
# t=1: (0.1509164515360051+0.21034249300617786j)
# t=2: (0.16252853622954125+0.20150487492702515j)
# t=5: (0.19412708118635338+0.1712729285623981j)
# t=10: (0.23410692186626225+0.11051555927821717j)
# t=20: (0.25693552610194476-0.0316839886218612j)
#
# Results for input (-1+0j):
# t=0: (2.94556786348498e-16-4.810477380965351j)
# t=0.25: (-0.05196888314774625-4.810196655851364j)
# t=0.5: (-0.10393170079741845-4.809354513273961j)
# t=1: (-0.20781488185773234-4.8059864344021745j)
# t=2: (-0.4152417417145097-4.792521979993119j)
# t=5: (-1.0313291728684095-4.698622433221234j)
# t=10: (-2.014696673078448-4.368259372824134j)
# t=20: (-3.658978903173403-3.1229098640388635j)
#
# Results for input (-1+1j):
# t=0: (0.5945034126549757-2.665905893244355j)
# t=0.25: (0.5133724039426641-2.682710814486631j)
# t=0.5: (0.43176902404764-2.697047283450244j)
# t=1: (0.26744586030190365-2.7182643821197323j)
# t=2: (-0.06354453970652921-2.730650221241615j)
# t=5: (-1.0315800685673358-2.529096894432478j)
# t=10: (-2.289462779920527-1.4895800477490178j)
# t=20: (-2.196400549757462+1.623672739291546j)
#
# Results for input (-1+2j):
# t=0: (0.2785925910875181-1.8282983689389474j)
# t=0.25: (0.15044690827425025-1.8432727648029716j)
# t=0.5: (0.021569044205515076-1.849276489334608j)
# t=1: (-0.23587387282463773-1.8342988507308122j)
# t=2: (-0.7320849818030868-1.698334577488207j)
# t=5: (-1.7517042920287746-0.5931448650723038j)
# t=10: (-0.8895210753987418+1.6214317790444153j)
# t=20: (1.392252513923799-1.217342061684609j)
#
# Results for input -2j:
# t=0: (0.2918503793793073+0.13697862691506052j)
# t=0.25: (-0.12699566390215714+0.29633070972383424j)
# t=0.5: (-0.30046968341397023-0.11686640887992342j)
# t=1: (0.3077048880686634+0.09621585126179703j)
# t=2: (0.3178962140415565+0.05368226218618065j)
# t=5: (0.3131552973486243-0.07663907565906358j)
# t=10: (0.19560860172175987-0.2562753657842261j)
# t=20: (-0.20910443401868775-0.2453877010958479j)
#
# Results for input -1j:
# t=0: (0.3223969419448345+0.3223969419448344j)
# t=0.25: (0.3223969419448345+0.3223969419448344j)
# t=0.5: (0.3223969419448344+0.3223969419448345j)
# t=1: (0.32239694194483437+0.32239694194483454j)
# t=2: (0.3223969419448343+0.3223969419448346j)
# t=5: (0.322396941944834+0.3223969419448349j)
# t=10: (0.32239694194483354+0.32239694194483537j)
# t=20: (0.3223969419448326+0.3223969419448363j)
#
# Results for input 0j:
# t=0: 0j
# t=0.25: 0j
# t=0.5: 0j
# t=1: 0j
# t=2: 0j
# t=5: 0j
# t=10: 0j
# t=20: 0j
#
# Results for input 1j:
# t=20: (0.33756141726294325+0.21737240061206103j)
#
# Results for input (2-1j):
# t=0: (0.5226749470359452-0.0900089801468423j)
# t=0.25: (0.4166909156597365+0.32811491519398067j)
# t=0.5: (0.03508599350292328+0.52920666079143j)
# t=1: (-0.5299829488338894-0.02021857342736586j)
# t=2: (0.5142981628411957+0.12956896412441407j)
# t=5: (-0.34086024057592545-0.4063311619364493j)
# t=10: (-0.17953585678349837+0.49905670308605005j)
# t=20: (-0.34554771897591374-0.40235244584399593j)
#
# Results for input (2+0j):
# t=0: (0.6650637002129894-0.24018799857404816j)
# t=0.25: (0.7065950788033323+0.026895996187401038j)
# t=0.5: (0.6448805994880212+0.290050017072867j)
# t=1: (0.2615527085885477+0.6569552348752495j)
# t=2: (-0.6481606480600348+0.28264425397731985j)
# t=5: (0.34406118728791113+0.6177555336879088j)
# t=10: (-0.5543514972167428+0.4389697227982308j)
# t=20: (0.38624022595671464-0.5922993228536616j)
#
# Results for input (2+1j):
# t=0: (0.6792552025237488-0.49962040369354166j)
# t=0.25: (0.7277608452794823-0.42587830423792444j)
# t=0.5: (0.7682922302537951-0.34746974958135j)
# t=1: (0.8237480189194378-0.18013156100133584j)
# t=2: (0.8257939711466947+0.17050658392052948j)
# t=5: (0.09297289191418448+0.8380717268298639j)
# t=10: (-0.7722441324003717-0.33859589175841115j)
# t=20: (0.09272248036927891+0.8380994687843712j)
#
# Results for input (2+2j):
# t=0: (0.5386781752670272-0.6966113851711j)
# t=0.25: (0.4804656629305073-0.7379663577723314j)
# t=0.5: (0.41909383987815807-0.7744688191497404j)
# t=1: (0.28850458833083514-0.8319896038840078j)
# t=2: (0.008226754947035423-0.8805531891726098j)
# t=5: (-0.7233871927877251-0.5021479540630505j)
# t=10: (-0.46428931975306176+0.7482493073984445j)
# t=20: (0.38499067537440046-0.79197460712688j)
#
#
# Testing with alpha=0j and beta=(-1-1j)
#
# Results for input (-2-2j):
# t=0: (1+0j)
# t=0.25: (0.9999977788309156+0.0021076843300660477j)
# t=0.5: (0.9999911153335296+0.004215359297085548j)
# t=1: (0.9999644614919929+0.00843064369004828j)
# t=2: (0.9998578484939429+0.016860688155099994j)
# t=5: (0.9991116635920951+0.04214123484469947j)
# t=10: (0.9964482326515278+0.0842075985030257j)
# t=20: (0.9858181607087064+0.1678170254083388j)
#
# Results for input (-2-1j):
# t=0: (1+0j)
# t=0.25: (0.9999973829378833-0.0022878193513188906j)
# t=0.5: (0.9999895317652314-0.004575626727907073j)
# t=1: (0.9999581272800937-0.009151157658344544j)
# t=2: (0.9998325126270242-0.018301548948966198j)
# t=5: (0.9989533573245323-0.04574046228499772j)
# t=10: (0.9958156202199094-0.09138517673034925j)
# t=20: (0.9832974989479256-0.18200557288927754j)
#
# Results for input (-2+0j):
# t=0: (1+0j)
# t=0.25: (-0.6085990373877396-0.7934779213631069j)
# t=0.5: (-0.2592144233814335+0.9658197982600227j)
# t=1: (-0.8656157654220619-0.5007088441926885j)
# t=2: (0.49858130669444406+0.8668429388388998j)
# t=5: (0.8680648831380517-0.496450761569081j)
# t=10: (0.507073282674959-0.8619029446505222j)
# t=20: (-0.4857533719944822-0.8740959109823075j)
#
# Results for input (-2+1j):
# t=0: (1+0j)
# t=0.25: (0.037210738624260234-0.9993074406462893j)
# t=0.5: (-0.997230721862074-0.07436993595833503j)
# t=1: (0.9889382252511063+0.1483279698411333j)
# t=2: (0.9559976267256157+0.29337439849958j)
# t=5: (0.7355036154445521+0.6775207979597323j)
# t=10: (0.08193113666401515+0.9966379928765221j)
# t=20: (-0.986574577689885+0.16331136719783218j)
#
# Results for input (-2+2j):
# t=0: (1+0j)
# t=0.25: (0.6195992770173946-0.7849182988818147j)
# t=0.5: (-0.23219347183904404-0.9726696210097913j)
# t=1: (-0.8921723832706622+0.4516950725092612j)
# t=2: (0.5919431229417065-0.8059797387044042j)
# t=5: (0.6979461009649618+0.7161502915923497j)
# t=10: (-0.02574248029561481+0.9996686074436018j)
# t=20: (-0.9986746494164598-0.05146789885852322j)
#
# Results for input (-1-2j):
# t=0: (1+0j)
# t=0.25: (0.9999880444972564+0.004889873470048605j)
# t=0.5: (0.9999521782748938+0.009779630018305837j)
# t=1: (0.9998087176734101+0.019558324679054922j)
# t=2: (0.9992349438714974+0.03910916703441222j)
# t=5: (0.9952215997483721+0.09764203702448596j)
# t=10: (0.9809320652114178+0.19435092858039738j)
# t=20: (0.9244554331198745+0.38129011549625197j)
#
# Results for input (-1-1j):
# t=0: (1+0j)
# t=0.25: (0.9999746617013433-0.007118704607155772j)
# t=0.5: (0.9998986480894321-0.014237048462584775j)
# t=1: (0.999594612902148-0.02847121102104449j)
# t=2: (0.9983787802859904-0.05691933831887267j)
# t=5: (0.9898817470988611-0.1418947735489447j)
# t=10: (0.9597317464789874-0.2809180926896533j)
# t=20: (0.8421700503992148-0.5392120234291741j)
#
# Results for input (-1+0j):
# t=0: (1+0j)
# t=0.25: (0.8785338539005159+0.47768008912943727j)
# t=0.5: (0.5436434648985856+0.8393162592688529j)
# t=1: (-0.4089035661461205+0.9125775986692777j)
# t=2: (-0.6655957471859706-0.7463124689618615j)
# t=5: (-0.8600314505373431-0.5102410254836762j)
# t=10: (0.4793081918267329+0.8776466585407751j)
# t=20: (-0.5405273144955757+0.8413264659359059j)
#
# Results for input (-1+1j):
# t=0: (1+0j)
# t=0.25: (-0.11733771850034792-0.9930920701612379j)
# t=0.5: (-0.9724637196342663+0.23305431554701422j)
# t=1: (0.8913713720098254-0.4532737331473349j)
# t=2: (0.5890858456773573-0.8080704588231108j)
# t=5: (-0.7042575076971305-0.709944619567066j)
# t=10: (-0.008042725704452178+0.9999676567585788j)
# t=20: (-0.9998706291264859-0.01608493115326607j)
#
# Results for input (-1+2j):
# t=0: (1+0j)
# t=0.25: (0.6849470727679227-0.7285928269662378j)
# t=0.5: (-0.061695015013308395-0.9980950481404602j)
# t=1: (-0.9923874502450153+0.12315497795946892j)
# t=2: (0.9696657028076054-0.24443490912435684j)
# t=5: (-0.8154198541682006+0.5788699866363003j)
# t=10: (0.3298190771433789-0.9440441601706405j)
# t=20: (-0.7824387527045797-0.6227275473801536j)
#
# Results for input -2j:
# t=0: (1+0j)
# t=0.25: (0.9998621671369315+0.016602612090833486j)
# t=0.5: (0.9994487065435226+0.033200647410549185j)
# t=1: (0.9977954340230408+0.06636468822176188j)
# t=2: (0.9911914563144567+0.13243676577607336j)
# t=5: (0.9453703635585226+0.325998275616953j)
# t=10: (0.7874502485895463+0.6163782166789006j)
# t=20: (0.24015578800747656+0.970734359897963j)
#
# Results for input -1j:
# t=0: (1+0j)
# t=0.25: (1+3.182238222325855e-18j)
# t=0.5: (1+6.36447644465171e-18j)
# t=1: (1+1.272895288930342e-17j)
# t=2: (1+2.545790577860684e-17j)
# t=5: (1+6.364476444651711e-17j)
# t=10: (1+1.2728952889303422e-16j)
# t=20: (1+2.5457905778606844e-16j)
#
# Results for input 0j:
# t=0: 0j
# t=0.25: 0j
# t=0.5: 0j
# t=1: 0j
# t=2: 0j
# t=5: 0j
# t=10: 0j
# t=20: 0j
#
# Results for input 1j:
# t=0: (1+0j)
# t=0.25: (1+7.36391965871245e-17j)
# t=0.5: (1+1.47278393174249e-16j)
# t=1: (1+2.94556786348498e-16j)
# t=2: (1+5.89113572696996e-16j)
# t=5: (1+1.47278393174249e-15j)
# t=10: (1+2.94556786348498e-15j)
# t=20: (1+5.89113572696996e-15j)
#
# Results for input 2j:
# t=0: (1+0j)
# t=0.25: (0.9270934873155162-0.3748301825856007j)
# t=0.5: (0.7190046684456904-0.6950052422487925j)
# t=1: (0.03393542649339457-0.9994240275422196j)
# t=2: (-0.9976967736574228-0.0678317612447827j)
# t=5: (0.1688962428741154-0.9856338362409277j)
# t=10: (-0.9429481182860157-0.33293970358138764j)
# t=20: (0.7783023075582755+0.6278897339895465j)
#
# Results for input (1-2j):
# t=0: (1+0j)
# t=0.25: (0.999377936232495+0.035266706277722853j)
# t=0.5: (0.9975125188566416+0.07048953627509648j)
# t=1: (0.9900624505514437+0.1406283897656162j)
# t=2: (0.9604473119838599+0.2784617763768991j)
# t=5: (0.7613001379188916+0.6483996452842002j)
# t=10: (0.15915579999064663+0.987253478762844j)
# t=20: (-0.9493388626586746+0.3142542344120986j)
#
# Results for input (1-1j):
# t=0: (1+0j)
# t=0.25: (0.9973394105039318+0.07289787552233401j)
# t=0.5: (0.9893717994886606+0.1454078484008672j)
# t=1: (0.9577131152468609+0.2877248492642807j)
# t=2: (0.8344288222316939+0.5511157234456554j)
# t=5: (0.11131326481717607+0.9937853677106245j)
# t=10: (-0.9752187141514824+0.2212429876148149j)
# t=20: (0.9021030808625418-0.4315206037935043j)
#
# Results for input (1+0j):
# t=0: (1+0j)
# t=0.25: (0.9689124217106447+0.24740395925452294j)
# t=0.5: (0.8775825618903728+0.479425538604203j)
# t=1: (0.5403023058681398+0.8414709848078965j)
# t=2: (-0.4161468365471424+0.9092974268256817j)
# t=5: (0.2836621854632263-0.9589242746631385j)
# t=10: (-0.8390715290764524-0.5440211108893699j)
# t=20: (0.40808206181339196+0.9129452507276277j)
#
# Results for input (1+1j):
# t=0: (1+0j)
# t=0.25: (0.9864621515149473+0.16398909606587014j)
# t=0.5: (0.9462151527429976+0.3235380730602593j)
# t=1: (0.7906462305609087+0.6122732544377767j)
# t=2: (0.2502429238003471+0.9681830813889766j)
# t=5: (-0.9883076015707605-0.15247322610035804j)
# t=10: (0.9535038306450981+0.3013808967820023j)
# t=20: (0.8183391101097521+0.5747356791297883j)
#
# Results for input (1+2j):
# t=0: (1+0j)
# t=0.25: (0.9936047434863997-0.11291418742268768j)
# t=0.5: (0.9745007725573483-0.22438414446018967j)
# t=1: (0.8993035114297374-0.437325044252149j)
# t=2: (0.6174936113397119-0.7865758958642458j)
# t=5: (-0.6383200409914352-0.7697710862774026j)
# t=10: (-0.18509505053738473+0.9827206226932266j)
# t=20: (-0.9314796445331259-0.36379344664306595j)
#
# Results for input (2-2j):
# t=0: (1+0j)
# t=0.25: (0.9992394662364653+0.038993449648162905j)
# t=0.5: (0.9969590217690724+0.07792758762629758j)
# t=1: (0.9878545821734914+0.1553812230574746j)
# t=2: (0.9517133510423267+0.3069881063620953j)
# t=5: (0.7108665864123629+0.7033268772927952j)
# t=10: (0.01066260735513076+0.9999431527863923j)
# t=20: (-0.9997726176087807+0.021324002431225654j)
#
# Results for input (2-1j):
# t=0: (1+0j)
# t=0.25: (0.997804823165216+0.06622337101229461j)
# t=0.5: (0.991228930263536+0.13215599800465425j)
# t=1: (0.9650695843827877+0.2619936970601268j)
# t=2: (0.862718605401533+0.5056842966654531j)
# t=5: (0.24290449923976484+0.9700502070764581j)
# t=10: (-0.8819948084981581+0.4712591195746745j)
# t=20: (0.5558296844354053-0.8312961938445513j)
#
# Results for input (2+0j):
# t=0: (1+0j)
# t=0.25: (0.9953806819296065+0.09600676039400366j)
# t=0.5: (0.9815654039172967+0.19112654926167139j)
# t=1: (0.9269412843346518+0.3752064170507032j)
# t=2: (0.7184402892079476+0.6955886362231636j)
# t=5: (-0.3450583255294479+0.9385812442100117j)
# t=10: (-0.7618695039656271-0.6477305450009049j)
# t=20: (0.1608902821456615+0.9869722980464495j)
#
# Results for input (2+1j):
# t=0: (1+0j)
# t=0.25: (0.9985989117602875+0.05291704291784974j)
# t=0.5: (0.9943995731376609+0.10568580294267435j)
# t=1: (0.9776610221127244+0.21018783466581265j)
# t=2: (0.911642148316994+0.4109849065500774j)
# t=5: (0.489887684973809+0.8717855562642697j)
# t=10: (-0.5200201122220042+0.8541540159038147j)
# t=20: (-0.4591581657692283-0.8883545344103546j)
#
# Results for input (2+2j):
# t=0: (1+0j)
# t=0.25: (0.9988108178166261-0.04875397637611438j)
# t=0.5: (0.9952460995750345-0.09739199803207854j)
# t=1: (0.9810295974386393-0.19385801234249123j)
# t=2: (0.924838142101237-0.3803608956172178j)
# t=5: (0.560782095435559-0.827963430013007j)
# t=10: (-0.3710468828778073-0.9286141344534138j)
# t=20: (-0.7246484214133255+0.6891187599704244j)
#
#
# Testing with alpha=0j and beta=(-0.5-0.5j)
#
# Results for input (-2-2j):
# t=0: (1+0j)
# t=0.25: (0.999344749486747+0.03619491225670791j)
# t=0.5: (0.9973798566534584+0.07234239104374911j)
# t=1: (0.9895331569161466+0.14430568721836584j)
# t=2: (0.9583517372728704+0.28559052446828714j)
# t=5: (0.7491248244760976+0.6624288621079669j)
# t=10: (0.12237600529268831+0.9924838101090636j)
# t=20: (-0.9700482266572078+0.24291240799762848j)
#
# Results for input (-2-1j):
# t=0: (1+0j)
# t=0.25: (0.9996629226276547+0.025962301969120877j)
# t=0.5: (0.9986519177529284+0.051907101329186175j)
# t=1: (0.9946113056632032+0.10367425257477471j)
# t=2: (0.9785032987061236+0.20623116743410674j)
# t=5: (0.8681646048425108+0.49627635335430514j)
# t=10: (0.5074195622027058+0.8616991284050451j)
# t=20: (-0.48505077578802885+0.8744859889714822j)
#
# Results for input (-2+0j):
# t=0: (1+0j)
# t=0.25: (0.95857073848914-0.28485459327942164j)
# t=0.5: (0.8377157213752305-0.5461065556837577j)
# t=1: (0.4035352596784457-0.9149640944847232j)
# t=2: (-0.6743185883924987-0.7384405469286934j)
# t=5: (0.8746462964184029+0.48476164881472555j)
# t=10: (0.5300122876768573+0.8479899615629564j)
# t=20: (-0.43817394982308855+0.8988901989099856j)
#
# Results for input (-2+1j):
# t=0: (1+0j)
# t=0.25: (0.9941470616150145-0.10803527147294303j)
# t=0.5: (0.976656760235535-0.21480589537121345j)
# t=1: (0.9077168546275426-0.41958325970548527j)
# t=2: (0.6478997763498388-0.7617255935084688j)
# t=5: (-0.5597917726850826-0.8286333153054448j)
# t=10: (-0.37326634246818535+0.9277242249615041j)
# t=20: (-0.7213444751608468-0.6925764565410252j)
#
# Results for input (-2+2j):
# t=0: (1+0j)
# t=0.25: (0.9981257849515368-0.0611957303647778j)
# t=0.5: (0.9925101651702428-0.12216207281205287j)
# t=1: (0.9701528559325254-0.24249419812845965j)
# t=2: (0.8823931277480708-0.47051287772278555j)
# t=5: (0.3392471952446924-0.9406972629483992j)
# t=10: (-0.7698226810372191-0.6382578160592066j)
# t=20: (0.18525392047866396+0.9826906863033174j)
#
# Results for input (-1-2j):
# t=0: (1+0j)
# t=0.25: (0.9987809638981753+0.049361788405930584j)
# t=0.5: (0.9951268276907362+0.09860322920762624j)
# t=1: (0.9805548063796566+0.1962454373628953j)
# t=2: (0.9229754566284919+0.38485881367252966j)
# t=5: (0.5506637539881005+0.8347271590428412j)
# t=10: (-0.3935388600874655+0.9193079819087062j)
# t=20: (-0.6902543312021164-0.7235668305393212j)
#
# Results for input (-1-1j):
# t=0: (1+0j)
# t=0.25: (0.999397799813426+0.03469924679417731j)
# t=0.5: (0.9975919245438335+0.06935670180256777j)
# t=1: (0.9903792958301394+0.13837937126247268j)
# t=2: (0.9617022992180055+0.27409612853669024j)
# t=5: (0.7686142084950126+0.639712590543273j)
# t=10: (0.18153560300082952+0.9833843728894237j)
# t=20: (-0.9340896496862504+0.3570385502281483j)
#
# Results for input (-1+0j):
# t=0: (1+0j)
# t=0.25: (1+7.36391965871245e-17j)
# t=0.5: (1+1.47278393174249e-16j)
# t=1: (1+2.94556786348498e-16j)
# t=2: (1+5.89113572696996e-16j)
# t=5: (1+1.47278393174249e-15j)
# t=10: (1+2.94556786348498e-15j)
# t=20: (1+5.89113572696996e-15j)
#
# Results for input (-1+1j):
# t=0: (1+0j)
# t=0.25: (0.9889754942704255+0.1480792751622171j)
# t=0.5: (0.9561450565348648+0.29289354868952j)
# t=1: (0.8284267382721195+0.5600974373408766j)
# t=2: (0.37258172136836565+0.9279993862617505j)
# t=5: (-0.9857407395818549+0.1682711928067834j)
# t=10: (0.9433696113427646-0.3317435400953591j)
# t=20: (0.7798924472099977-0.6259135489704636j)
#
# Results for input (-1+2j):
# t=0: (1+0j)
# t=0.25: (0.9975755480510471+0.06959185247321008j)
# t=0.5: (0.9903139481386939+0.1388462607417003j)
# t=1: (0.9614434317560956+0.27500277731881556j)
# t=2: (0.8487469449338759+0.5287992279357188j)
# t=5: (0.17689753096155547+0.9842292738684953j)
# t=10: (-0.9374145270794111+0.3482154568948428j)
# t=20: (0.7574919911590318-0.6528444556936402j)
#
# Results for input -2j:
# t=0: (1+0j)
# t=0.25: (0.9973394105039318+0.07289787552233401j)
# t=0.5: (0.9893717994886606+0.1454078484008672j)
# t=1: (0.9577131152468609+0.2877248492642807j)
# t=2: (0.8344288222316939+0.5511157234456554j)
# t=5: (0.11131326481717607+0.9937853677106245j)
# t=10: (-0.9752187141514824+0.2212429876148149j)
# t=20: (0.9021030808625418-0.4315206037935043j)
#
# Results for input -1j:
# t=0: (1+0j)
# t=0.25: (0.9967536396176376+0.08051199854054435j)
# t=0.5: (0.9870356361820147+0.16050125515635502j)
# t=1: (0.9484786941864692+0.3168409169825295j)
# t=2: (0.7992236666513397+0.6010337184088662j)
# t=5: (-0.04117673801928296+0.9991518784679791j)
# t=10: (-0.9966089524921826-0.08228363028230085j)
# t=20: (0.9864588083751312+0.16400920516579579j)
#
# Results for input 0j:
# t=0: 0j
# t=0.25: 0j
# t=0.5: 0j
# t=1: 0j
# t=2: 0j
# t=5: 0j
# t=10: 0j
# t=20: 0j
#
# Results for input 1j:
# t=0: (1+0j)
# t=0.25: (0.9257731824982885+0.3780793760138082j)
# t=0.5: (0.7141119708660189+0.7000314943385406j)
# t=1: (0.01991181386829961+0.9998017401807592j)
# t=2: (-0.9992070393369484+0.039815732311362644j)
# t=5: (0.09940122657135039+0.9950474341236759j)
# t=10: (-0.9802387923122221+0.1978178708971367j)
# t=20: (0.9217361799074475-0.3878175017319687j)
#
# Results for input 2j:
# t=0: (1+0j)
# t=0.25: (0.9864621515149473+0.16398909606587014j)
# t=0.5: (0.9462151527429976+0.3235380730602593j)
# t=1: (0.7906462305609087+0.6122732544377767j)
# t=2: (0.2502429238003471+0.9681830813889766j)
# t=5: (-0.9883076015707605-0.15247322610035804j)
# t=10: (0.9535038306450981+0.3013808967820023j)
# t=20: (0.8183391101097521+0.5747356791297883j)
#
# Results for input (1-2j):
# t=0: (1+0j)
# t=0.25: (0.9954893300765139+0.09487356693944633j)
# t=0.5: (0.9819980125923727+0.18889124718903746j)
# t=1: (0.9286401934707399+0.3709816586714588j)
# t=2: (0.7247452178587465+0.689016958565519j)
# t=5: (-0.32360130966470574+0.946193527975798j)
# t=10: (-0.7905643847665744-0.6123789296984733j)
# t=20: (0.24998409292270476+0.9682499436021736j)
#
# Results for input (1-1j):
# t=0: (1+0j)
# t=0.25: (0.9904177281516181+0.13810403239220592j)
# t=0.5: (0.9618545524740251+0.2735613640209322j)
# t=1: (0.8503283602300141+0.5262524867290751j)
# t=2: (0.44611664042292926+0.8949748282146034j)
# t=5: (-0.9320900284561039+0.3622266953893645j)
# t=10: (0.7375836422946012-0.6752557816260665j)
# t=20: (0.08805925876114008-0.9961152377844837j)
#
# Results for input (1+0j):
# t=0: (1+0j)
# t=0.25: (0.9689124217106447+0.24740395925452294j)
# t=0.5: (0.8775825618903728+0.479425538604203j)
# t=1: (0.5403023058681398+0.8414709848078965j)
# t=2: (-0.4161468365471424+0.9092974268256817j)
# t=5: (0.2836621854632263-0.9589242746631385j)
# t=10: (-0.8390715290764524-0.5440211108893699j)
# t=20: (0.40808206181339196+0.9129452507276277j)
#
# Results for input (1+1j):
# t=0: (1+0j)
# t=0.25: (0.9656698729671274+0.25977239353644216j)
# t=0.5: (0.8650366071126957+0.5017087485334054j)
# t=1: (0.49657666329008837+0.8679928671801872j)
# t=2: (-0.5068232349513644+0.8620500034878685j)
# t=5: (0.5169986943156646-0.8559861856805272j)
# t=10: (-0.46542470015179593-0.8850874806981572j)
# t=20: (-0.5667596969772217+0.8238831506240966j)
#
# Results for input (1+2j):
# t=0: (1+0j)
# t=0.25: (0.9859623319567038+0.1669679009944683j)
# t=0.5: (0.9442434400750028+0.329248122052844j)
# t=1: (0.7831913482493511+0.6217807588108236j)
# t=2: (0.22677737594527272+0.9739466216171071j)
# t=5: (-0.9772997154233583-0.21186143167981974j)
# t=10: (0.9102294675331541+0.4141042337797462j)
# t=20: (0.6570353671313787+0.7538597524331263j)
#
# Results for input (2-2j):
# t=0: (1+0j)
# t=0.25: (0.995047658291681+0.09939898253122151j)
# t=0.5: (0.9802396845435158+0.19781344960853534j)
# t=1: (0.9217396783079429+0.38780918688547067j)
# t=2: (0.6992080691344602+0.7149182303293573j)
# t=5: (-0.40819098092724343+0.9128965566205488j)
# t=10: (-0.6667602461793096-0.7452722818640892j)
# t=20: (-0.11086154822981291+0.9938358602526319j)
#
# Results for input (2-1j):
# t=0: (1+0j)
# t=0.25: (0.9914749808872398+0.1302972074706414j)
# t=0.5: (0.9660452754507053+0.25837284257322984j)
# t=1: (0.8664869484412581+0.49919972774527505j)
# t=2: (0.5015992636380866+0.8651000975134203j)
# t=5: (-0.8637066016410034+0.503994946682751j)
# t=10: (0.4919781874365018-0.8706075252871952j)
# t=20: (-0.5159149261733885-0.8566398245187454j)
#
# Results for input (2+0j):
# t=0: (1+0j)
# t=0.25: (0.9862096338607578+0.16550093075336508j)
# t=0.5: (0.9452188838395397+0.3264372246437816j)
# t=1: (0.7868774767337305+0.6171092582429446j)
# t=2: (0.23835232678168533+0.9711787519904648j)
# t=5: (-0.9831698286259227-0.1826939738460842j)
# t=10: (0.9332458238406526+0.35923840591448686j)
# t=20: (0.7418955354320368+0.6705154841657361j)
#
# Results for input (2+1j):
# t=0: (1+0j)
# t=0.25: (0.9856162514708185+0.16899883087350662j)
# t=0.5: (0.9428787903267758+0.3331359883769929j)
# t=1: (0.7780408264961681+0.6282137154704278j)
# t=2: (0.21069505538968086+0.9775518368016805j)
# t=5: (-0.967743118408685-0.25193899414865073j)
# t=10: (0.8730534864547322+0.4876244556923254j)
# t=20: (0.5244447804215269+0.8514444622455516j)
#
# Results for input (2+2j):
# t=0: (1+0j)
# t=0.25: (0.9909457533003646+0.13426285419270984j)
# t=0.5: (0.9639469719680542+0.2660944103765038j)
# t=1: (0.8583875295327617+0.5130018022801112j)
# t=2: (0.4736583017147154+0.8807086994101577j)
# t=5: (-0.9012278110032678+0.4333456272702636j)
# t=10: (0.6244231346514836-0.7810862621452354j)
# t=20: (-0.22019149782403044-0.9754566644838765j)
#
#
# Testing with alpha=0j and beta=0j
#
# Results for input (-2-2j):
# t=0: (1+0j)
# t=0.25: (0.9689124217106447+0.24740395925452294j)
# t=0.5: (0.8775825618903728+0.479425538604203j)
# t=1: (0.5403023058681398+0.8414709848078965j)
# t=2: (-0.4161468365471424+0.9092974268256817j)
# t=5: (0.2836621854632263-0.9589242746631385j)
# t=10: (-0.8390715290764524-0.5440211108893699j)
# t=20: (0.40808206181339196+0.9129452507276277j)
#
# Results for input (
# Input (2-2j): [(6.003989597347272+1.560745963527877j), (-1.1382137768535883+6.098220104743966j), (-6.162752812894367-0.7101385885060625j), (6.201613912997772-0.15428519642301294j), (5.918952968726929-1.857367707730889j), (2.581223540587011-5.6410197731653335j), (-5.106091910912769-3.5230163844401856j), (3.590332775394168+5.05898503750043j)]
# Input (2-1j): [(3.350259315072876+1.1891502215003973j), (1.3586849718731542+3.2851622295912675j), (-1.5315937782728801+3.20819828344241j), (-3.0312462569302947-1.8573803749832984j), (2.5807255680608834+2.4450299118587178j), (-0.6587998427601532-3.493465112850881j), (-2.6870550108066533+2.3276707448489957j), (-0.6992534701349072-3.4855932510881575j)]
# Input (2+0j): [(1.5384778027279442+1.2779225526272695j), (0.9465938481414273+1.7618059162861284j), (0.21639603195104554+1.988258724954034j), (-1.2275425471712214+1.5789677941251332j), (-1.6178087177346274-1.1758805010807176j), (-1.0137480307361846+1.7240402925043565j), (-1.864682216107451-0.72315989444424j), (1.997812339347964+0.0935192854389642j)]
# Input (2+1j): [(0.41889893980777826+1.3426225685938753j), (0.2762550262787349+1.379055779845555j), (0.1305841172645005+1.4003783316618217j), (-0.1634383986371036+1.3969250421266832j), (-0.7175131047771391+1.2096638491509806j), (-1.372163986227315-0.30867082526610895j), (0.9535017467524777-1.0338984971503102j), (-1.3720716972419633-0.30908080027276735j)]
# Input (2+2j): [(-0.3244472096893367+1.2481068139109326j), (-0.22225528320524013+1.2702909902433592j), (-0.11860191305918193+1.2841223450375738j), (0.0903577316841019+1.2864183188725975j), (0.4957342218886955+1.1904974557110592j), (1.263138019563938+0.2598440962157675j), (0.19455357517608182-1.2748276421510087j), (-0.06260256622764858+1.2880673621778518j)]

# %% [markdown]
# Before we go into the mathematical details, that might interest some and bore others, let us check the data with graphs.
#
# ![Complex_Trajectory_Of_MIS.png](data:image/png;base64,...)
#
#
# 1. Complex Trajectory of MIS in the Complex Plane
#
# - Graph: The trajectory graph shows the path of an MIS input as it evolves over time in the complex plane.
#
# - Explanation: MIS transformations follow unique paths through complex space, with patterns that can either stabilize into loops or diverge. These trajectories are key to understanding how MIS adapts and oscillates under different configurations.
#
# - Significance: This visual captures the potential for MIS to exhibit stability or chaos, important for applications that rely on predictable (or oscillatory) transformations.

# %% [markdown]
# ![MIS_Magnitude_Stability_Over_Time.png](data:image/png;base64,...)
#
#
# 2. MIS Magnitude Stability Heatmap Over Time
#
# - Graph: The heatmap illustrates the magnitude of the MIS transformation over time, with color intensity indicating stability levels.
#
# - Explanation: Darker areas indicate low oscillations and high stability, while lighter regions represent potential instability or divergence.
#
# - Significance: This stability overview is crucial for applications where consistent output magnitude is needed, such as in simulations that rely on controlled oscillations or minimal energy spikes.

# %% [markdown]
# ![MIS_Phase_Evolution_Over_Time.png](data:image/png;base64,...)
#
#
# 3. MIS Phase Evolution Over Time
#
# - Graph: The phase evolution plot displays how the angle (phase) of the MIS transformation changes with time.
#
# - Explanation: Consistent phase values indicate coherent phase evolution, while rapid jumps suggest chaotic shifts. This coherence is vital for maintaining synchronized states.
#
# - Significance: Phase coherence or chaos impacts applications involving quantum-inspired processing, where consistent phase relationships can enhance stability or controlled oscillations.
